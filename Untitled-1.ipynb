# %%
# %pip install pyodbc

import pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conn_str = r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:\Users\gia.luongdo\Desktop\ERP-Import.mdb;'
conn = pyodbc.connect(conn_str)

# %%
# %pip install pandas

import pandas as pd
df = pd.read_sql("SELECT * FROM t_Art_MegaBase", conn)
# Out:
# ...
#   Using cached pandas-2.3.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.0-cp311-cp311-win_amd64.whl (11.1 MB)
# Using cached numpy-2.3.1-cp311-cp311-win_amd64.whl (13.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
# ...

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Strip whitespace from string columns
str_cols = df_cleaned.select_dtypes(include='object').columns
df_cleaned[str_cols] = df_cleaned[str_cols].apply(lambda x: x.str.strip())

# Replace empty strings with NaN
df_cleaned[str_cols] = df_cleaned[str_cols].replace('', pd.NA)

# Optionally, drop rows with all NaN values
df_cleaned = df_cleaned.dropna(how='all')

# Show summary of cleaned data
print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ArtNr                 481 non-null    object
#  1   ArtMain               481 non-null    object
#  2   ArtSort               472 non-null    object
#  3   ArtikelNeu            481 non-null    object
#  4   ArtGrp                481 non-null    object
#  5   Marke                 167 non-null    object
#  6   ProduktKat            273 non-null    object
#  7   Veredelung            129 non-null    object
#  8   Produktart            481 non-null    object
#  9   Produktgruppe         167 non-null    object
#  10  Materialart           179 non-null    object
#  11  Zusammensetzung       198 non-null    object
#  12  Gender                481 non-null    object
#  13  Grammatur             177 non-null    object
#  14  Inhaltsmenge          481 non-null    object
# ...
